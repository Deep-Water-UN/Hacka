# %%
import geomesa_pyspark
conf = geomesa_pyspark.configure(
    jars=['/usr/lib/spark/jars/geomesa-hbase-spark-runtime_2.11-2.1.0-m.2.jar'],
    packages=['geomesa_pyspark','pytz'],
    spark_home='/usr/lib/spark/').\
    setAppName('MyTestApp')
conf.get('spark.master')
# u'yarn'
from pyspark.sql import SparkSession
spark = ( SparkSession
    .builder
    .config(conf=conf)
    .getOrCreate()
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b243c2a9f9b7> in <module>()
# ----> 1 import geomesa_pyspark
#       2 conf = geomesa_pyspark.configure(
#       3     jars=['/usr/lib/spark/jars/geomesa-hbase-spark-runtime_2.11-2.1.0-m.2.jar'],
#       4     packages=['geomesa_pyspark','pytz'],
#       5     spark_home='/usr/lib/spark/').\
#
# ModuleNotFoundError: No module named 'geomesa_pyspark'
